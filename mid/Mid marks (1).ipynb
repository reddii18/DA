# %% [markdown]
# # Case study on DA
# # K.Gopi Krishna
# # 2211cs010304 group-4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 


df = pd.read_excel("MIDMARKS.xlsx")
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %% [markdown]
# # Importing pandas and reading Excel file data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %% [markdown]
# # Shows Execl Data info

# %%
df[df['DV'].isnull()]
# Out:
#       S.NO SECTION   DV M-II   PP BEEE   FL FIMS
# 564  565.0   SIGMA  NaN  NaN  NaN  NaN  NaN  NaN
# 601    NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# # Filtering rows where 'DV' subject column is null

# %%
df.rename(columns={'M-II':'M2'}, inplace=True)
df
# Out:
#      S.NO SECTION  DV  M2  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   NaN    ZETA  19   8   8   19  17   18
# 714   NaN    ZETA  12   1   7   10  20    8
# 715   NaN    ZETA  17   6  14   14  17   18
# 716   NaN    ZETA  12   1   6    7  15   12
# 717   NaN    ZETA  19  14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
columns_to_convert = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
for col in columns_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df['Total'] = df['DV'] + df['M2'] + df['PP'] + df['BEEE'] + df['FL'] + df['FIMS']
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0
#
# [718 rows x 9 columns]

# %%
df['PERCENTAGE'] = (df['Total'] /120)*100
print(df)
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  PERCENTAGE
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   74.166667
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   48.333333
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   71.666667
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   44.166667
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   87.500000
#
# [718 rows x 10 columns]

# %% [markdown]
# #Calculating percentage based on 'Total'column value

# %% [markdown]
# # Renaming column 'M-II' to 'M2' in dataframe

# %%
def assign_grade(percentage):
    if percentage >= 90:
        return 'A'
    elif percentage >= 80:
        return 'B'
    elif percentage >= 70:
        return 'C'
    elif percentage >= 60:
        return 'D'
    else:
        return 'F'
df['GRADE'] = df['PERCENTAGE'].apply(assign_grade)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  PERCENTAGE GRADE
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000     D
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000     C
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000     B
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333     C
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000     A
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...   ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   74.166667     C
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   48.333333     F
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   71.666667     C
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   44.166667     F
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   87.500000     B
#
# [718 rows x 11 columns]

# %% [markdown]
# # Assigning grades based on percentage values in dataframe

# %%
df[df['SECTION'] == 'BETA']['GRADE'].value_counts()
# Out:
# GRADE
# F    32
# C    17
# D    16
# B    15
# A    10
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'BETA' section in dataframe

# %%
df[df['SECTION'] == 'ALPHA']['GRADE'].value_counts()
# Out:
# GRADE
# A    23
# F    23
# C    18
# B    16
# D    10
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'ALPHA' section in dataframe

# %%
df[df['SECTION'] == 'EPSILON']['GRADE'].value_counts()
# Out:
# GRADE
# F    43
# C    15
# D    14
# B    11
# A     5
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'EPSILON' section in dataframe

# %%
df[df['SECTION'] == 'GAMMA']['GRADE'].value_counts()
# Out:
# GRADE
# F    31
# C    21
# D    15
# B    14
# A     9
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'GAMMA' section in dataframe

# %%
df[df['SECTION'] == 'OMEGA']['GRADE'].value_counts()
# Out:
# GRADE
# C    21
# F    21
# A    20
# B    15
# D    13
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'OMEGA' section in dataframe

# %%
df[df['SECTION'] == 'SIGMA']['GRADE'].value_counts()
# Out:
# GRADE
# A    20
# F    14
# B    13
# D    10
# C     6
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'SIGMA' section in dataframe

# %%
df[df['SECTION'] == 'ZETA']['GRADE'].value_counts()
# Out:
# GRADE
# F    36
# C    20
# D    16
# B    14
# A     4
# Name: count, dtype: int64

# %% [markdown]
# # Counting grade frequencies for 'ZETA' section in dataframe

# %%
a_grades = df[df['GRADE'] == 'A']
a_grades['SECTION'].value_counts()
# Out:
# SECTION
# ALPHA      23
# OMEGA      20
# SIGMA      20
# BETA       10
# GAMMA       9
# DELTA       8
# EPSILON     5
# ZETA        4
# Name: count, dtype: int64

# %% [markdown]
# # Counting sections with 'A' grades in dataframe

# %%
df.plot.line(x='BEEE',y='Total',color='blue')
plt.title("Line Graph of BEEE subject")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Plotting line graph of 'BEEE' vs 'Total' values

# %%
import matplotlib.pyplot as plt
df.plot.line(x='DV',y='Total',color='red')
plt.title("Line Graph of DV subject")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Plotting line graph of 'DV' vs 'Total' values

# %%
DF=df.sort_values("Total",ascending=True)
DF
# Out:
#       S.NO  SECTION    DV   M2    PP  BEEE    FL  FIMS  Total  PERCENTAGE  \
# 190  191.0    DELTA   5.0  0.0   1.0   1.0  10.0   5.0   22.0   18.333333
# 611    NaN      NaN   2.0  0.0   0.0   3.0  10.0   9.0   24.0   20.000000
# 635    NaN     ZETA   9.0  0.0   2.0   2.0   3.0   9.0   25.0   20.833333
# 357  358.0  EPSILON   9.0  0.0   2.0   3.0  11.0   1.0   26.0   21.666667
# 636    NaN     ZETA   9.0  0.0   5.0   3.0   4.0   5.0   26.0   21.666667
# ..     ...      ...   ...  ...   ...   ...   ...   ...    ...         ...
# 628    NaN     ZETA  17.0  3.0   8.0  16.0  15.0   NaN    NaN         NaN
# 650    NaN     ZETA   NaN  NaN   NaN   NaN   NaN   NaN    NaN         NaN
# 669    NaN     ZETA  16.0  6.0   NaN   NaN   8.0   9.0    NaN         NaN
# 673    NaN     ZETA   2.0  NaN   0.0   0.0   2.0   1.0    NaN         NaN
# 705    NaN     ZETA  16.0  0.0  11.0  16.0  20.0   NaN    NaN         NaN
#
#     GRADE
# 190     F
# 611     F
# 635     F
# 357     F
# 636     F
# ..    ...
# 628     F
# 650     F
# 669     F
# 673     F
# 705     F
#
# [718 rows x 11 columns]

# %% [markdown]
# # Sorting dataframe by 'Total' in ascending order

# %%
d=df.loc[(df['Total']>=25) & (df['Total']<=75)]
d=d.reset_index()
d
# Out:
#      index  S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  \
# 0        0   1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1       20  21.0   ALPHA   4.0   2.0   5.0   3.0  16.0   9.0   39.0
# 2       25  26.0   ALPHA   6.0  10.0  10.0  11.0  13.0  10.0   60.0
# 3       27  28.0   ALPHA   5.0   4.0   3.0  12.0  13.0   5.0   42.0
# 4       29  30.0   ALPHA   8.0   2.0  11.0  10.0  13.0  12.0   56.0
# ..     ...   ...     ...   ...   ...   ...   ...   ...   ...    ...
# 227    700   NaN    ZETA  17.0   7.0   7.0  12.0  13.0   9.0   65.0
# 228    701   NaN    ZETA  15.0   4.0   3.0  13.0  14.0  13.0   62.0
# 229    710   NaN    ZETA  18.0   1.0   6.0  12.0  11.0   9.0   57.0
# 230    714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0
# 231    716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0
#
#      PERCENTAGE GRADE
# 0     60.000000     D
# 1     32.500000     F
# 2     50.000000     F
# 3     35.000000     F
# 4     46.666667     F
# ..          ...   ...
# 227   54.166667     F
# 228   51.666667     F
# 229   47.500000     F
# 230   48.333333     F
# 231   44.166667     F
#
# [232 rows x 12 columns]

# %% [markdown]
# # Filtering rows where 'Total' is between 25 and 75

# %%
df.plot.scatter(x = 'FIMS', y = 'Total',color='green',s=30)
plt.title("Scatter Plot for FIMS subject")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for FIMS subject')

# %% [markdown]
# # Creating scatter plot for 'FIMS' vs 'Total' values

# %%
df['M2'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of M2 subject")
# Out:
# Text(0.5, 1.0, 'Pie Chart of M2 subject')

# %% [markdown]
# # Creating pie chart for 'M2' subject data distribution

# %%
df.boxplot(by='DV', column =['Total'], grid = False,color='orange')
plt.title("Boxplot of DV")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Creating boxplot to visualize 'Total' distribution by 'DV'

# %%
df.boxplot(by='M2', column =['Total'], grid = False,color='green')
plt.title("Boxplot of M2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Creating boxplot to visualize 'Total' distribution by 'M2

# %%
plt.hist(df['DV'],color='red',edgecolor='white',bins=9)
plt.xlabel("Marks scored in DV subject")
plt.ylabel("Students")
plt.title("Histogram of DV subject")
# Out:
# Text(0.5, 1.0, 'Histogram of DV subject')

# %% [markdown]
# # Creating histogram to visualize 'DV' subject marks distribution

# %%
df.plot()
plt.show()

# %% [markdown]
# # Plotting all columns in the dataframe for visualization

# %%
df['BEEE'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of BEEE subject")
# Out:
# Text(0.5, 1.0, 'Pie Chart of BEEE subject')

# %% [markdown]
# # Creating pie chart for 'BEEE' subject data distribution

# %%
plt.hist(df['DV'], color='green', bins=8)
plt.ylim(0, 250)  
plt.xlabel("Marks scored in DV")
plt.ylabel("No. of students")
plt.title("Histogram of DV")
plt.show()

# %% [markdown]
# # Creating histogram to visualize 'DV' subject marks distribution

# %%
plt.hist(df['BEEE'], color='yellow', bins=8)
plt.ylim(0, 250)  
plt.xlabel("Marks scored in BEEE")
plt.ylabel("No. of students")
plt.title("Histogram of BEEE")
plt.show()

# %% [markdown]
# # Creating histogram to visualize 'BEEE' subject marks distribution

# %%
DF=df.sort_values("Total",ascending=True)
DF.head(10)
# Out:
#       S.NO  SECTION    DV   M2   PP  BEEE    FL  FIMS  Total  PERCENTAGE GRADE
# 190  191.0    DELTA   5.0  0.0  1.0   1.0  10.0   5.0   22.0   18.333333     F
# 611    NaN      NaN   2.0  0.0  0.0   3.0  10.0   9.0   24.0   20.000000     F
# 635    NaN     ZETA   9.0  0.0  2.0   2.0   3.0   9.0   25.0   20.833333     F
# 357  358.0  EPSILON   9.0  0.0  2.0   3.0  11.0   1.0   26.0   21.666667     F
# 636    NaN     ZETA   9.0  0.0  5.0   3.0   4.0   5.0   26.0   21.666667     F
# 358  359.0    GAMMA   6.0  0.0  3.0   3.0  10.0   4.0   26.0   21.666667     F
# 427  428.0    GAMMA   2.0  5.0  1.0   2.0  10.0   6.0   26.0   21.666667     F
# 350  351.0  EPSILON  14.0  0.0  1.0   6.0   6.0   1.0   28.0   23.333333     F
# 638    NaN     ZETA  11.0  0.0  3.0   4.0   4.0   7.0   29.0   24.166667     F
# 194  195.0    DELTA   6.0  0.0  1.0   0.0  10.0  13.0   30.0   25.000000     F

# %%
students_less_than_11 = DF[
    (DF['DV'] < 10) |
    (DF['PP'] < 10) |
    (DF['BEEE'] < 10) | 
    (DF['FL'] < 10) |
    (DF['FIMS'] < 10) | 
    (DF['M2'] < 10)
]
section_wise_counts = students_less_than_11.groupby('SECTION').size()
print(section_wise_counts)
# Out:
# SECTION
# ALPHA      38
# BETA       54
# DELTA      56
# EPSILON    66
# GAMMA      53
# OMEGA      60
# SIGMA      23
# ZETA       68
# dtype: int64

# %%
DF
# Out:
#       S.NO  SECTION    DV   M2    PP  BEEE    FL  FIMS  Total  PERCENTAGE  \
# 190  191.0    DELTA   5.0  0.0   1.0   1.0  10.0   5.0   22.0   18.333333
# 611    NaN      NaN   2.0  0.0   0.0   3.0  10.0   9.0   24.0   20.000000
# 635    NaN     ZETA   9.0  0.0   2.0   2.0   3.0   9.0   25.0   20.833333
# 357  358.0  EPSILON   9.0  0.0   2.0   3.0  11.0   1.0   26.0   21.666667
# 636    NaN     ZETA   9.0  0.0   5.0   3.0   4.0   5.0   26.0   21.666667
# ..     ...      ...   ...  ...   ...   ...   ...   ...    ...         ...
# 628    NaN     ZETA  17.0  3.0   8.0  16.0  15.0   NaN    NaN         NaN
# 650    NaN     ZETA   NaN  NaN   NaN   NaN   NaN   NaN    NaN         NaN
# 669    NaN     ZETA  16.0  6.0   NaN   NaN   8.0   9.0    NaN         NaN
# 673    NaN     ZETA   2.0  NaN   0.0   0.0   2.0   1.0    NaN         NaN
# 705    NaN     ZETA  16.0  0.0  11.0  16.0  20.0   NaN    NaN         NaN
#
#     GRADE
# 190     F
# 611     F
# 635     F
# 357     F
# 636     F
# ..    ...
# 628     F
# 650     F
# 669     F
# 673     F
# 705     F
#
# [718 rows x 11 columns]

# %%
top = df[
    (df['DV'] >= 15) &
     (df['M2'] >= 15) &
(df['PP'] >= 15) &
(df['BEEE'] >= 15) &
(df['FL'] >= 15) &
(df['FIMS'] >= 15) 
]
section_top = top.groupby('SECTION').size()
print(section_top)
# Out:
# SECTION
# ALPHA      24
# BETA       15
# DELTA      11
# EPSILON     4
# GAMMA      14
# OMEGA      18
# SIGMA      21
# ZETA        5
# dtype: int64

# %% [markdown]
# ## here we can see how many toppers are there in each section

# %%
df.head(10)
# Out:
#    S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  PERCENTAGE GRADE
# 0   1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000     D
# 1   2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000     C
# 2   3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000     B
# 3   4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333     C
# 4   5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000     A
# 5   6.0   ALPHA  17.0  16.0  18.0  10.0  15.0   9.0   85.0   70.833333     C
# 6   7.0   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0   94.0   78.333333     C
# 7   8.0   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0  105.0   87.500000     B
# 8   9.0   ALPHA  10.0  18.0   NaN  20.0  19.0  15.0    NaN         NaN     F
# 9  10.0   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0  112.0   93.333333     A

# %%
def failed(df):
     return ((df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1))

df['backlog'] = failed(df)


h = df.groupby('SECTION')['backlog'].sum()

print(h)
# Out:
# SECTION
# ALPHA       74
# BETA       100
# DELTA      128
# EPSILON    158
# GAMMA      117
# OMEGA       99
# SIGMA       45
# ZETA       163
# Name: backlog, dtype: int64

# %% [markdown]
# ## marks for a specific student across subjects

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  Total  PERCENTAGE  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   74.166667
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   48.333333
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   71.666667
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   44.166667
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   87.500000
#
#     GRADE  backlog
# 0       D        2
# 1       C        1
# 2       B        0
# 3       C        1
# 4       A        0
# ..    ...      ...
# 713     C        2
# 714     F        3
# 715     C        1
# 716     F        3
# 717     B        0
#
# [718 rows x 12 columns]

# %%
plt.hist(df['backlog'], color='yellow', bins=8)
plt.ylim(1, 720)  
plt.ylabel("no of students")
plt.xlabel("no of subjects")
plt.title("")
plt.show()

# %% [markdown]
# # using seaborn no of subjects who are failed

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(8, 6))
sns.histplot(df['BEEE'], color='yellow', bins=8, kde=False)


plt.ylim(0, 250)
plt.xlabel("Marks scored in BEEE")
plt.ylabel("No. of students")
plt.title("Histogram of BEEE")


plt.show()

# %% [markdown]
# # using seaborn visualize 'BEEE' subject marks distribution

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(8, 6))
sns.histplot(df['DV'], color='green', bins=8, kde=False)

plt.ylim(0, 250)
plt.xlabel("Marks scored in DV")
plt.ylabel("No. of students")
plt.title("Histogram of DV")
plt.show()

# %% [markdown]
# # using seaborn to visualize 'DV' subject marks distribution

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df)

plt.show()
